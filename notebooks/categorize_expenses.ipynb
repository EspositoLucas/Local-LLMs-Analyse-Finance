# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="llama2")
# Out:
# C:\Users\esposito\AppData\Local\Temp\ipykernel_18036\166534559.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama2")

# %% [markdown]
# ### Read transaction data

# %%
# Read the transactions_debit_card_2024.csv file
import pandas as pd
pd.set_option('display.max_rows', None)
df = pd.read_csv("../data/transactions_2024_no_categorized.csv")
df
# Out:
#          Date               Name / Description Expense/Income  \
# 0    19/01/24                 TRANSF. CLIENTE          Income
# 1    19/01/24          TRANSFERENCIA INMEDIATA         Income
# 2    22/01/24                      IMP PAIS SD        Expense
# 3    22/01/24                   APPLE.COM/BILL        Expense
# 4    22/01/24                       RG 4815/20        Expense
# 5    23/01/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 6    28/02/24                 TRANSF. CLIENTE          Income
# 7    29/02/24               OPENPAY*VIDA POINT        Expense
# 8    29/02/24                   DIA TIENDA 268        Expense
# 9    29/02/24                           FEI LI        Expense
# 10   29/02/24                   MERPAGO*HAKUNA        Expense
# 11   01/03/24                INTERESES GANADOS         Income
# 12   01/03/24              JULIO CESAR ESTRADA        Expense
# 13   04/03/24                 TRANSF. CLIENTE          Income
# 14   04/03/24                   DIA TIENDA 679        Expense
# 15   04/03/24                           FEI LI        Expense
# 16   05/03/24                COTO SUCURSAL 163        Expense
# 17   05/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 18   08/03/24                 TRANSF. CLIENTE          Income
# 19   11/03/24                      IMP PAIS SD        Expense
# 20   11/03/24                   DIA TIENDA 268        Expense
# 21   11/03/24                   DIA TIENDA 679        Expense
# 22   11/03/24                           FEI LI        Expense
# 23   11/03/24                   APPLE.COM/BILL        Expense
# 24   11/03/24                       RG 4815/20        Expense
# 25   12/03/24                COTO SUCURSAL 163        Expense
# 26   12/03/24                  MERPAGO*JUANLIN        Expense
# 27   12/03/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 28   13/03/24                   DIA TIENDA 679        Expense
# 29   13/03/24                           FEI LI        Expense
# 30   14/03/24                 TRANSF. CLIENTE          Income
# 31   14/03/24                 VERDULERIA PAOLA        Expense
# 32   14/03/24                           FEI LI        Expense
# 33   14/03/24                   DIA TIENDA 268        Expense
# 34   15/03/24                   DIA TIENDA 679        Expense
# 35   15/03/24              JULIO CESAR ESTRADA        Expense
# 36   18/03/24                 TRANSF. CLIENTE          Income
# 37   18/03/24                 TRANSF. CLIENTE          Income
# 38   18/03/24                 VERDULERIA PAOLA        Expense
# 39   18/03/24              JULIO CESAR ESTRADA        Expense
# 40   18/03/24                           FEI LI        Expense
# 41   18/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 42   18/03/24                        FARMACITY        Expense
# 43   18/03/24                   MERPAGO*HAKUNA        Expense
# 44   18/03/24                   DIA TIENDA 679        Expense
# 45   18/03/24                   DIA TIENDA 268        Expense
# 46   18/03/24                COTO SUCURSAL 163        Expense
# 47   03/04/24                INTERESES GANADOS         Income
# 48   03/04/24                 TRANSF. CLIENTE          Income
# 49   03/04/24              JULIO CESAR ESTRADA        Expense
# 50   03/04/24                COTO SUCURSAL 163        Expense
# 51   03/04/24         PVS*SUPER URUBURU JOSE E        Expense
# 52   05/04/24                   DIA TIENDA 268        Expense
# 53   10/04/24                 TRANSF. CLIENTE          Income
# 54   11/04/24                   MERPAGO*HAKUNA        Expense
# 55   11/04/24                   DIA TIENDA 268        Expense
# 56   11/04/24                 VERDULERIA PAOLA        Expense
# 57   11/04/24                           FEI LI        Expense
# 58   12/04/24                   DIA TIENDA 679        Expense
# 59   15/04/24                 VERDULERIA PAOLA        Expense
# 60   15/04/24                  MERPAGO*JUANLIN        Expense
# 61   15/04/24                         PIGMENTO        Expense
# 62   15/04/24                           FEI LI        Expense
# 63   16/04/24                   DIA TIENDA 268        Expense
# 64   16/04/24                           FEI LI        Expense
# 65   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 66   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 67   22/04/24                         PIGMENTO        Expense
# 68   23/04/24                 VERDULERIA PAOLA        Expense
# 69   02/05/24                INTERESES GANADOS         Income
# 70   24/05/24                 TRANSF. CLIENTE          Income
# 71   27/05/24         MERPAGO*LANATURALEZA1855        Expense
# 72   27/05/24           Market Avenida Sta. Fe        Expense
# 73   27/05/24                   DIA TIENDA 679        Expense
# 74   28/05/24                       NEW GARDEN        Expense
# 75   28/05/24                  MERPAGO*JUANLIN        Expense
# 76   29/05/24                COTO SUCURSAL 163        Expense
# 77   30/05/24         MERPAGO*LANATURALEZA1855        Expense
# 78   30/05/24                         LA FINCA        Expense
# 79   30/05/24                   DIA TIENDA 268        Expense
# 80   31/05/24                  MERPAGO*JUANLIN        Expense
# 81   03/06/24                INTERESES GANADOS         Income
# 82   06/06/24                  MERPAGO*JUANLIN        Expense
# 83   06/06/24                       NEW GARDEN        Expense
# 84   01/07/24                INTERESES GANADOS         Income
# 85   01/07/24                 TRANSF. CLIENTE          Income
# 86   01/07/24                    TRANSFERENCIA        Expense
# 87   03/07/24                COTO SUCURSAL 163        Expense
# 88   04/07/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 89   05/07/24                       NEW GARDEN        Expense
# 90   08/07/24                 VERDULERIA PAOLA        Expense
# 91   10/07/24                      IMP PAIS SD        Expense
# 92   10/07/24                   APPLE.COM BILL        Expense
# 93   10/07/24                COTO SUCURSAL 163        Expense
# 94   10/07/24                       RG 4815/20        Expense
# 95   11/07/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 96   12/07/24                  MERPAGO*JUANLIN        Expense
# 97   12/07/24                 VERDULERIA PAOLA        Expense
# 98   12/07/24                       NEW GARDEN        Expense
# 99   15/07/24                 TRANSF. CLIENTE          Income
# 100  15/07/24                   DIA TIENDA 268        Expense
# 101  15/07/24                    TRANSFERENCIA        Expense
# 102  15/07/24                    TRANSFERENCIA        Expense
# 103  16/07/24                   DIA TIENDA 679        Expense
# 104  19/07/24                    TRANSFERENCIA        Expense
# 105  22/07/24                 TRANSF. CLIENTE          Income
# 106  22/07/24                    TRANSFERENCIA        Expense
# 107  22/07/24                   DIA TIENDA 679        Expense
# 108  25/07/24  REINTEGRO MODO. 100% en tu Prim         Income
# 109  25/07/24  REINTEGRO MODO. 20% en cualquie         Income
# 110  29/07/24                    TRANSFERENCIA        Expense
# 111  01/08/24                INTERESES GANADOS         Income
# 112  07/08/24                 TRANSF. CLIENTE          Income
# 113  09/08/24                 VERDULERIA PAOLA        Expense
# 114  12/08/24                      IMP PAIS SD        Expense
# 115  12/08/24                   APPLE.COM/BILL        Expense
# 116  12/08/24                       RG 4815/20        Expense
# 117  13/08/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 118  26/08/24                 TRANSF. CLIENTE          Income
# 119  26/08/24                 VERDULERIA PAOLA        Expense
# 120  26/08/24                    TRANSFERENCIA        Expense
# 121  26/08/24                   DIA TIENDA 679        Expense
# 122  27/08/24                 VERDULERIA PAOLA        Expense
# 123  28/08/24                 TRANSF. CLIENTE          Income
# 124  28/08/24                COTO SUCURSAL 163        Expense
#
#      Amount (Argentinian Peso)
# 0                      2000.00
# 1                       980.00
# 2                       130.49
# 3                      1731.30
# 4                       489.36
# 5                       363.57
# 6                     30000.00
# 7                      2900.00
# 8                      3518.75
# 9                      3000.00
# 10                     1802.50
# 11                        0.07
# 12                     2593.00
# 13                    10000.00
# 14                     6310.00
# 15                     5800.00
# 16                     3870.38
# 17                     7500.00
# 18                    40000.00
# 19                      202.48
# 20                     2690.00
# 21                     4970.00
# 22                     3000.00
# 23                     2705.95
# 24                      759.31
# 25                     8790.73
# 26                     2850.00
# 27                      568.24
# 28                     3557.90
# 29                     2950.00
# 30                    30000.00
# 31                     1700.00
# 32                     3000.00
# 33                     3829.50
# 34                     8620.05
# 35                     1360.00
# 36                    10000.00
# 37                    20000.00
# 38                     1215.00
# 39                      620.00
# 40                     3000.00
# 41                     6750.00
# 42                    12006.04
# 43                     1767.50
# 44                     3779.00
# 45                     7603.15
# 46                    13184.08
# 47                        0.46
# 48                    20000.00
# 49                     4323.00
# 50                     6815.93
# 51                     7280.00
# 52                     1974.00
# 53                    50000.00
# 54                     1767.50
# 55                     6505.10
# 56                     2095.00
# 57                     5200.00
# 58                     6789.00
# 59                     7311.00
# 60                     3000.00
# 61                     2790.00
# 62                     5900.00
# 63                     4369.00
# 64                     4650.00
# 65                     3000.00
# 66                     7600.00
# 67                     4218.57
# 68                     5885.00
# 69                        0.26
# 70                   100000.00
# 71                    11900.00
# 72                     8836.44
# 73                     8578.60
# 74                     7495.00
# 75                     4700.00
# 76                    14979.32
# 77                     5800.00
# 78                     7760.00
# 79                     4237.40
# 80                     7840.00
# 81                        0.73
# 82                    14000.00
# 83                     4400.00
# 84                        0.15
# 85                   100000.00
# 86                    30000.00
# 87                    19067.60
# 88                    10000.00
# 89                     9400.00
# 90                    11287.00
# 91                      219.70
# 92                     2900.30
# 93                    11432.29
# 94                      823.89
# 95                      609.06
# 96                    10750.00
# 97                     4338.00
# 98                     4400.00
# 99                    50000.00
# 100                    9481.70
# 101                   20000.00
# 102                   10000.00
# 103                    7595.90
# 104                    8388.09
# 105                   50000.00
# 106                   30000.00
# 107                    9075.41
# 108                    5000.00
# 109                    1000.00
# 110                   16924.00
# 111                       0.94
# 112                   20000.00
# 113                    3612.00
# 114                     224.60
# 115                    2972.06
# 116                     842.28
# 117                     624.13
# 118                   50000.00
# 119                    8552.00
# 120                   30000.00
# 121                    5436.25
# 122                    7346.00
# 123                   30000.00
# 124                    8689.48

# %%
# Get unique transactions in the Name / Description column
unique_transactions = df["Name / Description"].unique()
len(unique_transactions)
# Out:
# 28

# %%
unique_transactions[1:10]
# Out:
# array(['TRANSFERENCIA INMEDIATA', 'IMP PAIS SD', 'APPLE.COM/BILL',
#        'RG 4815/20', 'IVA SERV DIGIT-RG AFIP 4240', 'OPENPAY*VIDA POINT',
#        'DIA TIENDA 268', 'FEI LI', 'MERPAGO*HAKUNA'], dtype=object)

# %% [markdown]
# ### Categorise bank transactions with Llama2

# %%
# Get index list
#https://stackoverflow.com/questions/47518609/for-loop-range-and-interval-how-to-include-last-step
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    yield stop

index_list = list(hop(0, len(unique_transactions), 30))
index_list
# Out:
# [0, 28]

# %%
def categorize_transactions(transaction_names, llm):
    response = llm.invoke("Can you add an appropriate category to the following expenses. For example: TRANSF. CLIENTE - Bank Transfer , DIA TIENDA 268 - Groceries, etc.. Categories should be less than 4 words. " + transaction_names)
    response = response.split('\n')

    print(response)

    # Put in dataframe
    categories_df = pd.DataFrame({'Transaction vs category': response})
    categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)
    
    return categories_df

# %%
# Test out the function
categorize_transactions('TRANSF. CLIENTE, APPLE.COM/BILL,IVA SERV DIGIT-RG AFIP 4240,DIA TIENDA 268',
                        llm)
# Out:
# ['Of course! Here are the appropriate categories for each expense you provided:', '', '1. TRANSF. CLIENTE - Client Transfer', '2. APPLE.COM/BILL - Apple Subscription (Bill)', '3. IVA SERV DIGIT-RG AFIP 4240 - Italian VAT Service (Digital Receipt)', '4. DIA TIENDA 268 - Groceries']
#                              Transaction vs category  \
# 0  Of course! Here are the appropriate categories...
# 1
# 2               1. TRANSF. CLIENTE - Client Transfer
# 3      2. APPLE.COM/BILL - Apple Subscription (Bill)
# 4  3. IVA SERV DIGIT-RG AFIP 4240 - Italian VAT S...
# 5                      4. DIA TIENDA 268 - Groceries
#
#                                          Transaction  \
# 0  Of course! Here are the appropriate categories...
# 1
# 2                                 1. TRANSF. CLIENTE
# 3                                  2. APPLE.COM/BILL
# 4                     3. IVA SERV DIGIT-RG AFIP 4240
# 5                                  4. DIA TIENDA 268
#
#                                 Category
# 0                                   None
# 1                                   None
# 2                        Client Transfer
# 3              Apple Subscription (Bill)
# 4  Italian VAT Service (Digital Receipt)
# 5                              Groceries

# %%
# Intialise the categories_df_all dataframe
categories_df_all = pd.DataFrame()

# Loop through the index_list
for i in range(0, len(index_list)-1):
    transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
    transaction_names = ','.join(transaction_names)

    categories_df = categorize_transactions(transaction_names, llm)
    categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# ['Here are the expenses with appropriate categories:', '', '1. TRANSF. CLIENTE - Bank Transfer', '2. TRANSFERENCIA INMEDIATA - Immediate Transaction', '3. IMP PAIS SD - Important Payment for Software Subscription', '4. APPLE.COM/BILL - Apple Bill', '5. RG 4815/20 - Utility Bills', '6. IVA SERV DIGIT-RG AFIP 4240 - Italian VAT Services', '7. OPENPAY*VIDA POINT - Openpay Point of Sale', '8. DIA TIENDA 268 - Groceries', '9. FEI LI - Fei Li', '10. MERPAGO*HAKUNA - Merpage Transaction', '11. INTERESES GANADOS - Investment Interests', '12. JULIO CESAR ESTRADA - Julio Cesar Estravia', '13. DIA TIENDA 679 - Groceries', '14. COTO SUCURSAL 163 - Local Store', '15. PVS*SUPER URUBURU JOSE E - Supermarket Jose E', '16. MERPAGO*JUANLIN - Merpage Transaction', "17. VERDULERIA PAOLA - Paola's Organic Market", '18. FARMACITY - Pharmacy', '19. PIGMENTO - Pigment', '20. TRANSF. CLIENTE TEJERINA MARIA - Tejerina Maria Transfer', '21. MERPAGO*LANATURALEZA1855 - Merpage Transaction', '22. Market Avenida Sta. Fe - Local Market', '23. NEW GARDEN - New Garden', '24. LA FINCA - La Finca', '25. TRANSFERENCIA - Transfer', '26. APPLE.COM BILL - Apple Bill', '27. REINTEGRO MODO. 100% en tu Prim - Complete Your First Mortgage', '28. REINTEGRO MODO. 20% en cualquiera - Any Mortgage Investment']

# %%
categories_df_all
# Out:
#                               Transaction vs category  \
# 0   Here are the expenses with appropriate categor...
# 1
# 2                  1. TRANSF. CLIENTE - Bank Transfer
# 3   2. TRANSFERENCIA INMEDIATA - Immediate Transac...
# 4   3. IMP PAIS SD - Important Payment for Softwar...
# 5                      4. APPLE.COM/BILL - Apple Bill
# 6                       5. RG 4815/20 - Utility Bills
# 7   6. IVA SERV DIGIT-RG AFIP 4240 - Italian VAT S...
# 8       7. OPENPAY*VIDA POINT - Openpay Point of Sale
# 9                       8. DIA TIENDA 268 - Groceries
# 10                                 9. FEI LI - Fei Li
# 11           10. MERPAGO*HAKUNA - Merpage Transaction
# 12       11. INTERESES GANADOS - Investment Interests
# 13     12. JULIO CESAR ESTRADA - Julio Cesar Estravia
# 14                     13. DIA TIENDA 679 - Groceries
# 15                14. COTO SUCURSAL 163 - Local Store
# 16  15. PVS*SUPER URUBURU JOSE E - Supermarket Jose E
# 17          16. MERPAGO*JUANLIN - Merpage Transaction
# 18      17. VERDULERIA PAOLA - Paola's Organic Market
# 19                           18. FARMACITY - Pharmacy
# 20                             19. PIGMENTO - Pigment
# 21  20. TRANSF. CLIENTE TEJERINA MARIA - Tejerina ...
# 22  21. MERPAGO*LANATURALEZA1855 - Merpage Transac...
# 23          22. Market Avenida Sta. Fe - Local Market
# 24                        23. NEW GARDEN - New Garden
# 25                            24. LA FINCA - La Finca
# 26                       25. TRANSFERENCIA - Transfer
# 27                    26. APPLE.COM BILL - Apple Bill
# 28  27. REINTEGRO MODO. 100% en tu Prim - Complete...
# 29  28. REINTEGRO MODO. 20% en cualquiera - Any Mo...
#
#                                           Transaction  \
# 0   Here are the expenses with appropriate categor...
# 1
# 2                                  1. TRANSF. CLIENTE
# 3                          2. TRANSFERENCIA INMEDIATA
# 4                                      3. IMP PAIS SD
# 5                                   4. APPLE.COM/BILL
# 6                                       5. RG 4815/20
# 7                      6. IVA SERV DIGIT-RG AFIP 4240
# 8                               7. OPENPAY*VIDA POINT
# 9                                   8. DIA TIENDA 268
# 10                                          9. FEI LI
# 11                                 10. MERPAGO*HAKUNA
# 12                              11. INTERESES GANADOS
# 13                            12. JULIO CESAR ESTRADA
# 14                                 13. DIA TIENDA 679
# 15                              14. COTO SUCURSAL 163
# 16                       15. PVS*SUPER URUBURU JOSE E
# 17                                16. MERPAGO*JUANLIN
# 18                               17. VERDULERIA PAOLA
# 19                                      18. FARMACITY
# 20                                       19. PIGMENTO
# 21                 20. TRANSF. CLIENTE TEJERINA MARIA
# 22                       21. MERPAGO*LANATURALEZA1855
# 23                         22. Market Avenida Sta. Fe
# 24                                     23. NEW GARDEN
# 25                                       24. LA FINCA
# 26                                  25. TRANSFERENCIA
# 27                                 26. APPLE.COM BILL
# 28                27. REINTEGRO MODO. 100% en tu Prim
# 29              28. REINTEGRO MODO. 20% en cualquiera
#
#                                        Category
# 0                                          None
# 1                                          None
# 2                                 Bank Transfer
# 3                         Immediate Transaction
# 4   Important Payment for Software Subscription
# 5                                    Apple Bill
# 6                                 Utility Bills
# 7                          Italian VAT Services
# 8                         Openpay Point of Sale
# 9                                     Groceries
# 10                                       Fei Li
# 11                          Merpage Transaction
# 12                         Investment Interests
# 13                         Julio Cesar Estravia
# 14                                    Groceries
# 15                                  Local Store
# 16                           Supermarket Jose E
# 17                          Merpage Transaction
# 18                       Paola's Organic Market
# 19                                     Pharmacy
# 20                                      Pigment
# 21                      Tejerina Maria Transfer
# 22                          Merpage Transaction
# 23                                 Local Market
# 24                                   New Garden
# 25                                     La Finca
# 26                                     Transfer
# 27                                   Apple Bill
# 28                 Complete Your First Mortgage
# 29                      Any Mortgage Investment

# %%
categories_df_all.to_csv("categories_df_all.csv", index=False)

# %%
# Get unique categories in categories_df_all
unique_categories = categories_df_all["Category"].unique()
unique_categories
# Out:
# array([None, 'Bank Transfer', 'Immediate Transaction',
#        'Important Payment for Software Subscription', 'Apple Bill',
#        'Utility Bills', 'Italian VAT Services', 'Openpay Point of Sale',
#        'Groceries', 'Fei Li', 'Merpage Transaction',
#        'Investment Interests', 'Julio Cesar Estravia', 'Local Store',
#        'Supermarket Jose E', "Paola's Organic Market", 'Pharmacy',
#        'Pigment', 'Tejerina Maria Transfer', 'Local Market', 'New Garden',
#        'La Finca', 'Transfer', 'Complete Your First Mortgage',
#        'Any Mortgage Investment'], dtype=object)

# %%
# Drop NA values
categories_df_all = categories_df_all.dropna()

# First split the columns
categories_df_all[['Transaction', 'Category']] = categories_df_all['Transaction vs category'].str.split(' - ', expand=True)

# Clean up the Transaction column
categories_df_all['Transaction'] = categories_df_all['Transaction'].str.strip() 
categories_df_all['Transaction'] = categories_df_all['Transaction'].str.replace(r'^\d+\.\s*', '', regex=True)

# Standardize basic categories
categories_df_all.loc[categories_df_all['Category'].str.contains("Transfer|BANKING", case=False), 'Category'] = "Banking"
categories_df_all.loc[categories_df_all['Category'].str.contains("Groceries|Supermarket", case=False), 'Category'] = "Groceries"
categories_df_all.loc[categories_df_all['Category'].str.contains("Insurance", case=False), 'Category'] = "Insurance"
categories_df_all.loc[categories_df_all['Category'].str.contains("Merchant|Services", case=False), 'Category'] = "Services"
categories_df_all.loc[categories_df_all['Category'].str.contains("Rent|Mortgage", case=False), 'Category'] = "Housing"
categories_df_all.loc[categories_df_all['Category'].str.contains("Utilities", case=False), 'Category'] = "Utilities"
categories_df_all.loc[categories_df_all['Category'].str.contains("Pharmacy", case=False), 'Category'] = "Healthcare"
categories_df_all.loc[categories_df_all['Category'].str.contains("Home Improvement", case=False), 'Category'] = "Home Improvement"
categories_df_all.loc[categories_df_all['Category'].str.contains("Online Shopping|Shopping", case=False), 'Category'] = "Shopping"
categories_df_all.loc[categories_df_all['Category'].str.contains("Taxes", case=False), 'Category'] = "Taxes"
categories_df_all.loc[categories_df_all['Category'].str.contains("Miscellaneous", case=False), 'Category'] = "Miscellaneous"

categories_df_all
# Out:
# C:\Users\esposito\AppData\Local\Temp\ipykernel_18036\3739756680.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categories_df_all[['Transaction', 'Category']] = categories_df_all['Transaction vs category'].str.split(' - ', expand=True)
# C:\Users\esposito\AppData\Local\Temp\ipykernel_18036\3739756680.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categories_df_all['Transaction'] = categories_df_all['Transaction'].str.strip()
# C:\Users\esposito\AppData\Local\Temp\ipykernel_18036\3739756680.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categories_df_all['Transaction'] = categories_df_all['Transaction'].str.replace(r'^\d+\.\s*', '', regex=True)
#                               Transaction vs category  \
# 2                  1. TRANSF. CLIENTE - Bank Transfer
# 3   2. TRANSFERENCIA INMEDIATA - Immediate Transac...
# 4   3. IMP PAIS SD - Important Payment for Softwar...
# 5                      4. APPLE.COM/BILL - Apple Bill
# 6                       5. RG 4815/20 - Utility Bills
# 7   6. IVA SERV DIGIT-RG AFIP 4240 - Italian VAT S...
# 8       7. OPENPAY*VIDA POINT - Openpay Point of Sale
# 9                       8. DIA TIENDA 268 - Groceries
# 10                                 9. FEI LI - Fei Li
# 11           10. MERPAGO*HAKUNA - Merpage Transaction
# 12       11. INTERESES GANADOS - Investment Interests
# 13     12. JULIO CESAR ESTRADA - Julio Cesar Estravia
# 14                     13. DIA TIENDA 679 - Groceries
# 15                14. COTO SUCURSAL 163 - Local Store
# 16  15. PVS*SUPER URUBURU JOSE E - Supermarket Jose E
# 17          16. MERPAGO*JUANLIN - Merpage Transaction
# 18      17. VERDULERIA PAOLA - Paola's Organic Market
# 19                           18. FARMACITY - Pharmacy
# 20                             19. PIGMENTO - Pigment
# 21  20. TRANSF. CLIENTE TEJERINA MARIA - Tejerina ...
# 22  21. MERPAGO*LANATURALEZA1855 - Merpage Transac...
# 23          22. Market Avenida Sta. Fe - Local Market
# 24                        23. NEW GARDEN - New Garden
# 25                            24. LA FINCA - La Finca
# 26                       25. TRANSFERENCIA - Transfer
# 27                    26. APPLE.COM BILL - Apple Bill
# 28  27. REINTEGRO MODO. 100% en tu Prim - Complete...
# 29  28. REINTEGRO MODO. 20% en cualquiera - Any Mo...
#
#                           Transaction  \
# 2                     TRANSF. CLIENTE
# 3             TRANSFERENCIA INMEDIATA
# 4                         IMP PAIS SD
# 5                      APPLE.COM/BILL
# 6                          RG 4815/20
# 7         IVA SERV DIGIT-RG AFIP 4240
# 8                  OPENPAY*VIDA POINT
# 9                      DIA TIENDA 268
# 10                             FEI LI
# 11                     MERPAGO*HAKUNA
# 12                  INTERESES GANADOS
# 13                JULIO CESAR ESTRADA
# 14                     DIA TIENDA 679
# 15                  COTO SUCURSAL 163
# 16           PVS*SUPER URUBURU JOSE E
# 17                    MERPAGO*JUANLIN
# 18                   VERDULERIA PAOLA
# 19                          FARMACITY
# 20                           PIGMENTO
# 21     TRANSF. CLIENTE TEJERINA MARIA
# 22           MERPAGO*LANATURALEZA1855
# 23             Market Avenida Sta. Fe
# 24                         NEW GARDEN
# 25                           LA FINCA
# 26                      TRANSFERENCIA
# 27                     APPLE.COM BILL
# 28    REINTEGRO MODO. 100% en tu Prim
# 29  REINTEGRO MODO. 20% en cualquiera
#
#                                        Category
# 2                                       Banking
# 3                         Immediate Transaction
# 4   Important Payment for Software Subscription
# 5                                    Apple Bill
# 6                                 Utility Bills
# 7                                      Services
# 8                         Openpay Point of Sale
# 9                                     Groceries
# 10                                       Fei Li
# 11                          Merpage Transaction
# 12                         Investment Interests
# 13                         Julio Cesar Estravia
# 14                                    Groceries
# 15                                  Local Store
# 16                                    Groceries
# 17                          Merpage Transaction
# 18                       Paola's Organic Market
# 19                                   Healthcare
# 20                                      Pigment
# 21                                      Banking
# 22                          Merpage Transaction
# 23                                 Local Market
# 24                                   New Garden
# 25                                     La Finca
# 26                                      Banking
# 27                                   Apple Bill
# 28                                      Housing
# 29                                      Housing

# %%
# Merge the categories_df_all with the transactions dataframe
df = pd.read_csv("../data/transactions_2024_no_categorized.csv")
df = pd.merge(df, categories_df_all, left_on='Name / Description', right_on='Transaction', how='left')

# Drop unnecessary columns after merge
df = df.drop(['Transaction vs category', 'Transaction'], axis=1)

# Standardize categories for NaN values based on transaction descriptions
mask = df['Category'].isna()
df.loc[mask & df['Name / Description'].str.contains('TRANSF|BANKING', case=False, na=False), 'Category'] = 'Banking'
df.loc[mask & df['Name / Description'].str.contains('SUPER|MERCADO|VERDULERIA|COTO|DIA|CARREFOUR', case=False, na=False), 'Category'] = 'Groceries'
df.loc[mask & df['Name / Description'].str.contains('SEGURO', case=False, na=False), 'Category'] = 'Insurance'
df.loc[mask & df['Name / Description'].str.contains('SERVICIOS|MERCHANT', case=False, na=False), 'Category'] = 'Services'
df.loc[mask & df['Name / Description'].str.contains('ALQUILER|RENTA', case=False, na=False), 'Category'] = 'Housing'
df.loc[mask & df['Name / Description'].str.contains('LUZ|GAS|AGUA|SERVICIOS', case=False, na=False), 'Category'] = 'Utilities'
df.loc[mask & df['Name / Description'].str.contains('FARMACIA|SALUD', case=False, na=False), 'Category'] = 'Healthcare'
df.loc[mask & df['Name / Description'].str.contains('EASY|SODIMAC', case=False, na=False), 'Category'] = 'Home Improvement'
df.loc[mask & df['Name / Description'].str.contains('SHOPPING|COMPRA|MERCADOLIBRE|AMAZON', case=False, na=False), 'Category'] = 'Shopping'
df.loc[mask & df['Name / Description'].str.contains('IMPUESTO|IMP|AFIP|ARBA', case=False, na=False), 'Category'] = 'Taxes'

# Fill remaining NaN with Miscellaneous
df['Category'] = df['Category'].fillna('Miscellaneous')
df
# Out:
#          Date               Name / Description Expense/Income  \
# 0    19/01/24                 TRANSF. CLIENTE          Income
# 1    19/01/24          TRANSFERENCIA INMEDIATA         Income
# 2    22/01/24                      IMP PAIS SD        Expense
# 3    22/01/24                   APPLE.COM/BILL        Expense
# 4    22/01/24                       RG 4815/20        Expense
# 5    23/01/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 6    28/02/24                 TRANSF. CLIENTE          Income
# 7    29/02/24               OPENPAY*VIDA POINT        Expense
# 8    29/02/24                   DIA TIENDA 268        Expense
# 9    29/02/24                           FEI LI        Expense
# 10   29/02/24                   MERPAGO*HAKUNA        Expense
# 11   01/03/24                INTERESES GANADOS         Income
# 12   01/03/24              JULIO CESAR ESTRADA        Expense
# 13   04/03/24                 TRANSF. CLIENTE          Income
# 14   04/03/24                   DIA TIENDA 679        Expense
# 15   04/03/24                           FEI LI        Expense
# 16   05/03/24                COTO SUCURSAL 163        Expense
# 17   05/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 18   08/03/24                 TRANSF. CLIENTE          Income
# 19   11/03/24                      IMP PAIS SD        Expense
# 20   11/03/24                   DIA TIENDA 268        Expense
# 21   11/03/24                   DIA TIENDA 679        Expense
# 22   11/03/24                           FEI LI        Expense
# 23   11/03/24                   APPLE.COM/BILL        Expense
# 24   11/03/24                       RG 4815/20        Expense
# 25   12/03/24                COTO SUCURSAL 163        Expense
# 26   12/03/24                  MERPAGO*JUANLIN        Expense
# 27   12/03/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 28   13/03/24                   DIA TIENDA 679        Expense
# 29   13/03/24                           FEI LI        Expense
# 30   14/03/24                 TRANSF. CLIENTE          Income
# 31   14/03/24                 VERDULERIA PAOLA        Expense
# 32   14/03/24                           FEI LI        Expense
# 33   14/03/24                   DIA TIENDA 268        Expense
# 34   15/03/24                   DIA TIENDA 679        Expense
# 35   15/03/24              JULIO CESAR ESTRADA        Expense
# 36   18/03/24                 TRANSF. CLIENTE          Income
# 37   18/03/24                 TRANSF. CLIENTE          Income
# 38   18/03/24                 VERDULERIA PAOLA        Expense
# 39   18/03/24              JULIO CESAR ESTRADA        Expense
# 40   18/03/24                           FEI LI        Expense
# 41   18/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 42   18/03/24                        FARMACITY        Expense
# 43   18/03/24                   MERPAGO*HAKUNA        Expense
# 44   18/03/24                   DIA TIENDA 679        Expense
# 45   18/03/24                   DIA TIENDA 268        Expense
# 46   18/03/24                COTO SUCURSAL 163        Expense
# 47   03/04/24                INTERESES GANADOS         Income
# 48   03/04/24                 TRANSF. CLIENTE          Income
# 49   03/04/24              JULIO CESAR ESTRADA        Expense
# 50   03/04/24                COTO SUCURSAL 163        Expense
# 51   03/04/24         PVS*SUPER URUBURU JOSE E        Expense
# 52   05/04/24                   DIA TIENDA 268        Expense
# 53   10/04/24                 TRANSF. CLIENTE          Income
# 54   11/04/24                   MERPAGO*HAKUNA        Expense
# 55   11/04/24                   DIA TIENDA 268        Expense
# 56   11/04/24                 VERDULERIA PAOLA        Expense
# 57   11/04/24                           FEI LI        Expense
# 58   12/04/24                   DIA TIENDA 679        Expense
# 59   15/04/24                 VERDULERIA PAOLA        Expense
# 60   15/04/24                  MERPAGO*JUANLIN        Expense
# 61   15/04/24                         PIGMENTO        Expense
# 62   15/04/24                           FEI LI        Expense
# 63   16/04/24                   DIA TIENDA 268        Expense
# 64   16/04/24                           FEI LI        Expense
# 65   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 66   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 67   22/04/24                         PIGMENTO        Expense
# 68   23/04/24                 VERDULERIA PAOLA        Expense
# 69   02/05/24                INTERESES GANADOS         Income
# 70   24/05/24                 TRANSF. CLIENTE          Income
# 71   27/05/24         MERPAGO*LANATURALEZA1855        Expense
# 72   27/05/24           Market Avenida Sta. Fe        Expense
# 73   27/05/24                   DIA TIENDA 679        Expense
# 74   28/05/24                       NEW GARDEN        Expense
# 75   28/05/24                  MERPAGO*JUANLIN        Expense
# 76   29/05/24                COTO SUCURSAL 163        Expense
# 77   30/05/24         MERPAGO*LANATURALEZA1855        Expense
# 78   30/05/24                         LA FINCA        Expense
# 79   30/05/24                   DIA TIENDA 268        Expense
# 80   31/05/24                  MERPAGO*JUANLIN        Expense
# 81   03/06/24                INTERESES GANADOS         Income
# 82   06/06/24                  MERPAGO*JUANLIN        Expense
# 83   06/06/24                       NEW GARDEN        Expense
# 84   01/07/24                INTERESES GANADOS         Income
# 85   01/07/24                 TRANSF. CLIENTE          Income
# 86   01/07/24                    TRANSFERENCIA        Expense
# 87   03/07/24                COTO SUCURSAL 163        Expense
# 88   04/07/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 89   05/07/24                       NEW GARDEN        Expense
# 90   08/07/24                 VERDULERIA PAOLA        Expense
# 91   10/07/24                      IMP PAIS SD        Expense
# 92   10/07/24                   APPLE.COM BILL        Expense
# 93   10/07/24                COTO SUCURSAL 163        Expense
# 94   10/07/24                       RG 4815/20        Expense
# 95   11/07/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 96   12/07/24                  MERPAGO*JUANLIN        Expense
# 97   12/07/24                 VERDULERIA PAOLA        Expense
# 98   12/07/24                       NEW GARDEN        Expense
# 99   15/07/24                 TRANSF. CLIENTE          Income
# 100  15/07/24                   DIA TIENDA 268        Expense
# 101  15/07/24                    TRANSFERENCIA        Expense
# 102  15/07/24                    TRANSFERENCIA        Expense
# 103  16/07/24                   DIA TIENDA 679        Expense
# 104  19/07/24                    TRANSFERENCIA        Expense
# 105  22/07/24                 TRANSF. CLIENTE          Income
# 106  22/07/24                    TRANSFERENCIA        Expense
# 107  22/07/24                   DIA TIENDA 679        Expense
# 108  25/07/24  REINTEGRO MODO. 100% en tu Prim         Income
# 109  25/07/24  REINTEGRO MODO. 20% en cualquie         Income
# 110  29/07/24                    TRANSFERENCIA        Expense
# 111  01/08/24                INTERESES GANADOS         Income
# 112  07/08/24                 TRANSF. CLIENTE          Income
# 113  09/08/24                 VERDULERIA PAOLA        Expense
# 114  12/08/24                      IMP PAIS SD        Expense
# 115  12/08/24                   APPLE.COM/BILL        Expense
# 116  12/08/24                       RG 4815/20        Expense
# 117  13/08/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 118  26/08/24                 TRANSF. CLIENTE          Income
# 119  26/08/24                 VERDULERIA PAOLA        Expense
# 120  26/08/24                    TRANSFERENCIA        Expense
# 121  26/08/24                   DIA TIENDA 679        Expense
# 122  27/08/24                 VERDULERIA PAOLA        Expense
# 123  28/08/24                 TRANSF. CLIENTE          Income
# 124  28/08/24                COTO SUCURSAL 163        Expense
#
#      Amount (Argentinian Peso)                                     Category
# 0                      2000.00                                      Banking
# 1                       980.00                        Immediate Transaction
# 2                       130.49  Important Payment for Software Subscription
# 3                      1731.30                                   Apple Bill
# 4                       489.36                                Utility Bills
# 5                       363.57                                     Services
# 6                     30000.00                                      Banking
# 7                      2900.00                        Openpay Point of Sale
# 8                      3518.75                                    Groceries
# 9                      3000.00                                       Fei Li
# 10                     1802.50                          Merpage Transaction
# 11                        0.07                         Investment Interests
# 12                     2593.00                         Julio Cesar Estravia
# 13                    10000.00                                      Banking
# 14                     6310.00                                    Groceries
# 15                     5800.00                                       Fei Li
# 16                     3870.38                                  Local Store
# 17                     7500.00                                    Groceries
# 18                    40000.00                                      Banking
# 19                      202.48  Important Payment for Software Subscription
# 20                     2690.00                                    Groceries
# 21                     4970.00                                    Groceries
# 22                     3000.00                                       Fei Li
# 23                     2705.95                                   Apple Bill
# 24                      759.31                                Utility Bills
# 25                     8790.73                                  Local Store
# 26                     2850.00                          Merpage Transaction
# 27                      568.24                                     Services
# 28                     3557.90                                    Groceries
# 29                     2950.00                                       Fei Li
# 30                    30000.00                                      Banking
# 31                     1700.00                       Paola's Organic Market
# 32                     3000.00                                       Fei Li
# 33                     3829.50                                    Groceries
# 34                     8620.05                                    Groceries
# 35                     1360.00                         Julio Cesar Estravia
# 36                    10000.00                                      Banking
# 37                    20000.00                                      Banking
# 38                     1215.00                       Paola's Organic Market
# 39                      620.00                         Julio Cesar Estravia
# 40                     3000.00                                       Fei Li
# 41                     6750.00                                    Groceries
# 42                    12006.04                                   Healthcare
# 43                     1767.50                          Merpage Transaction
# 44                     3779.00                                    Groceries
# 45                     7603.15                                    Groceries
# 46                    13184.08                                  Local Store
# 47                        0.46                         Investment Interests
# 48                    20000.00                                      Banking
# 49                     4323.00                         Julio Cesar Estravia
# 50                     6815.93                                  Local Store
# 51                     7280.00                                    Groceries
# 52                     1974.00                                    Groceries
# 53                    50000.00                                      Banking
# 54                     1767.50                          Merpage Transaction
# 55                     6505.10                                    Groceries
# 56                     2095.00                       Paola's Organic Market
# 57                     5200.00                                       Fei Li
# 58                     6789.00                                    Groceries
# 59                     7311.00                       Paola's Organic Market
# 60                     3000.00                          Merpage Transaction
# 61                     2790.00                                      Pigment
# 62                     5900.00                                       Fei Li
# 63                     4369.00                                    Groceries
# 64                     4650.00                                       Fei Li
# 65                     3000.00                                      Banking
# 66                     7600.00                                      Banking
# 67                     4218.57                                      Pigment
# 68                     5885.00                       Paola's Organic Market
# 69                        0.26                         Investment Interests
# 70                   100000.00                                      Banking
# 71                    11900.00                          Merpage Transaction
# 72                     8836.44                                 Local Market
# 73                     8578.60                                    Groceries
# 74                     7495.00                                   New Garden
# 75                     4700.00                          Merpage Transaction
# 76                    14979.32                                  Local Store
# 77                     5800.00                          Merpage Transaction
# 78                     7760.00                                     La Finca
# 79                     4237.40                                    Groceries
# 80                     7840.00                          Merpage Transaction
# 81                        0.73                         Investment Interests
# 82                    14000.00                          Merpage Transaction
# 83                     4400.00                                   New Garden
# 84                        0.15                         Investment Interests
# 85                   100000.00                                      Banking
# 86                    30000.00                                      Banking
# 87                    19067.60                                  Local Store
# 88                    10000.00                                      Banking
# 89                     9400.00                                   New Garden
# 90                    11287.00                       Paola's Organic Market
# 91                      219.70  Important Payment for Software Subscription
# 92                     2900.30                                   Apple Bill
# 93                    11432.29                                  Local Store
# 94                      823.89                                Utility Bills
# 95                      609.06                                     Services
# 96                    10750.00                          Merpage Transaction
# 97                     4338.00                       Paola's Organic Market
# 98                     4400.00                                   New Garden
# 99                    50000.00                                      Banking
# 100                    9481.70                                    Groceries
# 101                   20000.00                                      Banking
# 102                   10000.00                                      Banking
# 103                    7595.90                                    Groceries
# 104                    8388.09                                      Banking
# 105                   50000.00                                      Banking
# 106                   30000.00                                      Banking
# 107                    9075.41                                    Groceries
# 108                    5000.00                                      Housing
# 109                    1000.00                                Miscellaneous
# 110                   16924.00                                      Banking
# 111                       0.94                         Investment Interests
# 112                   20000.00                                      Banking
# 113                    3612.00                       Paola's Organic Market
# 114                     224.60  Important Payment for Software Subscription
# 115                    2972.06                                   Apple Bill
# 116                     842.28                                Utility Bills
# 117                     624.13                                     Services
# 118                   50000.00                                      Banking
# 119                    8552.00                       Paola's Organic Market
# 120                   30000.00                                      Banking
# 121                    5436.25                                    Groceries
# 122                    7346.00                       Paola's Organic Market
# 123                   30000.00                                      Banking
# 124                    8689.48                                  Local Store

# %%
df.to_csv("../data/transactions_2024_categorized.csv", index=False)
