# %%
import pandas as pd
import numpy as np
import plotly.express as px
import panel as pn

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Read transaction data with categories

# %%
# Read transactions_2022_2023_categorized.csv
df = pd.read_csv('../data/transactions_2024_categorized.csv')
# Add year and month columns
df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month
df['Month Name'] = pd.to_datetime(df['Date']).dt.strftime("%b")

df
# Out:
# C:\Users\esposito\AppData\Local\Temp\ipykernel_12700\3694866640.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Year'] = pd.to_datetime(df['Date']).dt.year
# C:\Users\esposito\AppData\Local\Temp\ipykernel_12700\3694866640.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Month'] = pd.to_datetime(df['Date']).dt.month
# C:\Users\esposito\AppData\Local\Temp\ipykernel_12700\3694866640.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Month Name'] = pd.to_datetime(df['Date']).dt.strftime("%b")
#          Date               Name / Description Expense/Income  \
# 0    19/01/24                 TRANSF. CLIENTE          Income
# 1    19/01/24          TRANSFERENCIA INMEDIATA         Income
# 2    22/01/24                      IMP PAIS SD        Expense
# 3    22/01/24                   APPLE.COM/BILL        Expense
# 4    22/01/24                       RG 4815/20        Expense
# 5    23/01/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 6    28/02/24                 TRANSF. CLIENTE          Income
# 7    29/02/24               OPENPAY*VIDA POINT        Expense
# 8    29/02/24                   DIA TIENDA 268        Expense
# 9    29/02/24                           FEI LI        Expense
# 10   29/02/24                   MERPAGO*HAKUNA        Expense
# 11   01/03/24                INTERESES GANADOS         Income
# 12   01/03/24              JULIO CESAR ESTRADA        Expense
# 13   04/03/24                 TRANSF. CLIENTE          Income
# 14   04/03/24                   DIA TIENDA 679        Expense
# 15   04/03/24                           FEI LI        Expense
# 16   05/03/24                COTO SUCURSAL 163        Expense
# 17   05/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 18   08/03/24                 TRANSF. CLIENTE          Income
# 19   11/03/24                      IMP PAIS SD        Expense
# 20   11/03/24                   DIA TIENDA 268        Expense
# 21   11/03/24                   DIA TIENDA 679        Expense
# 22   11/03/24                           FEI LI        Expense
# 23   11/03/24                   APPLE.COM/BILL        Expense
# 24   11/03/24                       RG 4815/20        Expense
# 25   12/03/24                COTO SUCURSAL 163        Expense
# 26   12/03/24                  MERPAGO*JUANLIN        Expense
# 27   12/03/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 28   13/03/24                   DIA TIENDA 679        Expense
# 29   13/03/24                           FEI LI        Expense
# 30   14/03/24                 TRANSF. CLIENTE          Income
# 31   14/03/24                 VERDULERIA PAOLA        Expense
# 32   14/03/24                           FEI LI        Expense
# 33   14/03/24                   DIA TIENDA 268        Expense
# 34   15/03/24                   DIA TIENDA 679        Expense
# 35   15/03/24              JULIO CESAR ESTRADA        Expense
# 36   18/03/24                 TRANSF. CLIENTE          Income
# 37   18/03/24                 TRANSF. CLIENTE          Income
# 38   18/03/24                 VERDULERIA PAOLA        Expense
# 39   18/03/24              JULIO CESAR ESTRADA        Expense
# 40   18/03/24                           FEI LI        Expense
# 41   18/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 42   18/03/24                        FARMACITY        Expense
# 43   18/03/24                   MERPAGO*HAKUNA        Expense
# 44   18/03/24                   DIA TIENDA 679        Expense
# 45   18/03/24                   DIA TIENDA 268        Expense
# 46   18/03/24                COTO SUCURSAL 163        Expense
# 47   03/04/24                INTERESES GANADOS         Income
# 48   03/04/24                 TRANSF. CLIENTE          Income
# 49   03/04/24              JULIO CESAR ESTRADA        Expense
# 50   03/04/24                COTO SUCURSAL 163        Expense
# 51   03/04/24         PVS*SUPER URUBURU JOSE E        Expense
# 52   05/04/24                   DIA TIENDA 268        Expense
# 53   10/04/24                 TRANSF. CLIENTE          Income
# 54   11/04/24                   MERPAGO*HAKUNA        Expense
# 55   11/04/24                   DIA TIENDA 268        Expense
# 56   11/04/24                 VERDULERIA PAOLA        Expense
# 57   11/04/24                           FEI LI        Expense
# 58   12/04/24                   DIA TIENDA 679        Expense
# 59   15/04/24                 VERDULERIA PAOLA        Expense
# 60   15/04/24                  MERPAGO*JUANLIN        Expense
# 61   15/04/24                         PIGMENTO        Expense
# 62   15/04/24                           FEI LI        Expense
# 63   16/04/24                   DIA TIENDA 268        Expense
# 64   16/04/24                           FEI LI        Expense
# 65   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 66   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 67   22/04/24                         PIGMENTO        Expense
# 68   23/04/24                 VERDULERIA PAOLA        Expense
# 69   02/05/24                INTERESES GANADOS         Income
# 70   24/05/24                 TRANSF. CLIENTE          Income
# 71   27/05/24         MERPAGO*LANATURALEZA1855        Expense
# 72   27/05/24           Market Avenida Sta. Fe        Expense
# 73   27/05/24                   DIA TIENDA 679        Expense
# 74   28/05/24                       NEW GARDEN        Expense
# 75   28/05/24                  MERPAGO*JUANLIN        Expense
# 76   29/05/24                COTO SUCURSAL 163        Expense
# 77   30/05/24         MERPAGO*LANATURALEZA1855        Expense
# 78   30/05/24                         LA FINCA        Expense
# 79   30/05/24                   DIA TIENDA 268        Expense
# 80   31/05/24                  MERPAGO*JUANLIN        Expense
# 81   03/06/24                INTERESES GANADOS         Income
# 82   06/06/24                  MERPAGO*JUANLIN        Expense
# 83   06/06/24                       NEW GARDEN        Expense
# 84   01/07/24                INTERESES GANADOS         Income
# 85   01/07/24                 TRANSF. CLIENTE          Income
# 86   01/07/24                    TRANSFERENCIA        Expense
# 87   03/07/24                COTO SUCURSAL 163        Expense
# 88   04/07/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 89   05/07/24                       NEW GARDEN        Expense
# 90   08/07/24                 VERDULERIA PAOLA        Expense
# 91   10/07/24                      IMP PAIS SD        Expense
# 92   10/07/24                   APPLE.COM BILL        Expense
# 93   10/07/24                COTO SUCURSAL 163        Expense
# 94   10/07/24                       RG 4815/20        Expense
# 95   11/07/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 96   12/07/24                  MERPAGO*JUANLIN        Expense
# 97   12/07/24                 VERDULERIA PAOLA        Expense
# 98   12/07/24                       NEW GARDEN        Expense
# 99   15/07/24                 TRANSF. CLIENTE          Income
# 100  15/07/24                   DIA TIENDA 268        Expense
# 101  15/07/24                    TRANSFERENCIA        Expense
# 102  15/07/24                    TRANSFERENCIA        Expense
# 103  16/07/24                   DIA TIENDA 679        Expense
# 104  19/07/24                    TRANSFERENCIA        Expense
# 105  22/07/24                 TRANSF. CLIENTE          Income
# 106  22/07/24                    TRANSFERENCIA        Expense
# 107  22/07/24                   DIA TIENDA 679        Expense
# 108  25/07/24  REINTEGRO MODO. 100% en tu Prim         Income
# 109  25/07/24  REINTEGRO MODO. 20% en cualquie         Income
# 110  29/07/24                    TRANSFERENCIA        Expense
# 111  01/08/24                INTERESES GANADOS         Income
# 112  07/08/24                 TRANSF. CLIENTE          Income
# 113  09/08/24                 VERDULERIA PAOLA        Expense
# 114  12/08/24                      IMP PAIS SD        Expense
# 115  12/08/24                   APPLE.COM/BILL        Expense
# 116  12/08/24                       RG 4815/20        Expense
# 117  13/08/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 118  26/08/24                 TRANSF. CLIENTE          Income
# 119  26/08/24                 VERDULERIA PAOLA        Expense
# 120  26/08/24                    TRANSFERENCIA        Expense
# 121  26/08/24                   DIA TIENDA 679        Expense
# 122  27/08/24                 VERDULERIA PAOLA        Expense
# 123  28/08/24                 TRANSF. CLIENTE          Income
# 124  28/08/24                COTO SUCURSAL 163        Expense
#
#      Amount (Argentinian Peso)                                     Category  \
# 0                      2000.00                                      Banking
# 1                       980.00                        Immediate Transaction
# 2                       130.49  Important Payment for Software Subscription
# 3                      1731.30                                   Apple Bill
# 4                       489.36                                Utility Bills
# 5                       363.57                                     Services
# 6                     30000.00                                      Banking
# 7                      2900.00                        Openpay Point of Sale
# 8                      3518.75                                    Groceries
# 9                      3000.00                                       Fei Li
# 10                     1802.50                          Merpage Transaction
# 11                        0.07                         Investment Interests
# 12                     2593.00                         Julio Cesar Estravia
# 13                    10000.00                                      Banking
# 14                     6310.00                                    Groceries
# 15                     5800.00                                       Fei Li
# 16                     3870.38                                  Local Store
# 17                     7500.00                                    Groceries
# 18                    40000.00                                      Banking
# 19                      202.48  Important Payment for Software Subscription
# 20                     2690.00                                    Groceries
# 21                     4970.00                                    Groceries
# 22                     3000.00                                       Fei Li
# 23                     2705.95                                   Apple Bill
# 24                      759.31                                Utility Bills
# 25                     8790.73                                  Local Store
# 26                     2850.00                          Merpage Transaction
# 27                      568.24                                     Services
# 28                     3557.90                                    Groceries
# 29                     2950.00                                       Fei Li
# 30                    30000.00                                      Banking
# 31                     1700.00                       Paola's Organic Market
# 32                     3000.00                                       Fei Li
# 33                     3829.50                                    Groceries
# 34                     8620.05                                    Groceries
# 35                     1360.00                         Julio Cesar Estravia
# 36                    10000.00                                      Banking
# 37                    20000.00                                      Banking
# 38                     1215.00                       Paola's Organic Market
# 39                      620.00                         Julio Cesar Estravia
# 40                     3000.00                                       Fei Li
# 41                     6750.00                                    Groceries
# 42                    12006.04                                   Healthcare
# 43                     1767.50                          Merpage Transaction
# 44                     3779.00                                    Groceries
# 45                     7603.15                                    Groceries
# 46                    13184.08                                  Local Store
# 47                        0.46                         Investment Interests
# 48                    20000.00                                      Banking
# 49                     4323.00                         Julio Cesar Estravia
# 50                     6815.93                                  Local Store
# 51                     7280.00                                    Groceries
# 52                     1974.00                                    Groceries
# 53                    50000.00                                      Banking
# 54                     1767.50                          Merpage Transaction
# 55                     6505.10                                    Groceries
# 56                     2095.00                       Paola's Organic Market
# 57                     5200.00                                       Fei Li
# 58                     6789.00                                    Groceries
# 59                     7311.00                       Paola's Organic Market
# 60                     3000.00                          Merpage Transaction
# 61                     2790.00                                      Pigment
# 62                     5900.00                                       Fei Li
# 63                     4369.00                                    Groceries
# 64                     4650.00                                       Fei Li
# 65                     3000.00                                      Banking
# 66                     7600.00                                      Banking
# 67                     4218.57                                      Pigment
# 68                     5885.00                       Paola's Organic Market
# 69                        0.26                         Investment Interests
# 70                   100000.00                                      Banking
# 71                    11900.00                          Merpage Transaction
# 72                     8836.44                                 Local Market
# 73                     8578.60                                    Groceries
# 74                     7495.00                                   New Garden
# 75                     4700.00                          Merpage Transaction
# 76                    14979.32                                  Local Store
# 77                     5800.00                          Merpage Transaction
# 78                     7760.00                                     La Finca
# 79                     4237.40                                    Groceries
# 80                     7840.00                          Merpage Transaction
# 81                        0.73                         Investment Interests
# 82                    14000.00                          Merpage Transaction
# 83                     4400.00                                   New Garden
# 84                        0.15                         Investment Interests
# 85                   100000.00                                      Banking
# 86                    30000.00                                      Banking
# 87                    19067.60                                  Local Store
# 88                    10000.00                                      Banking
# 89                     9400.00                                   New Garden
# 90                    11287.00                       Paola's Organic Market
# 91                      219.70  Important Payment for Software Subscription
# 92                     2900.30                                   Apple Bill
# 93                    11432.29                                  Local Store
# 94                      823.89                                Utility Bills
# 95                      609.06                                     Services
# 96                    10750.00                          Merpage Transaction
# 97                     4338.00                       Paola's Organic Market
# 98                     4400.00                                   New Garden
# 99                    50000.00                                      Banking
# 100                    9481.70                                    Groceries
# 101                   20000.00                                      Banking
# 102                   10000.00                                      Banking
# 103                    7595.90                                    Groceries
# 104                    8388.09                                      Banking
# 105                   50000.00                                      Banking
# 106                   30000.00                                      Banking
# 107                    9075.41                                    Groceries
# 108                    5000.00                                      Housing
# 109                    1000.00                                Miscellaneous
# 110                   16924.00                                      Banking
# 111                       0.94                         Investment Interests
# 112                   20000.00                                      Banking
# 113                    3612.00                       Paola's Organic Market
# 114                     224.60  Important Payment for Software Subscription
# 115                    2972.06                                   Apple Bill
# 116                     842.28                                Utility Bills
# 117                     624.13                                     Services
# 118                   50000.00                                      Banking
# 119                    8552.00                       Paola's Organic Market
# 120                   30000.00                                      Banking
# 121                    5436.25                                    Groceries
# 122                    7346.00                       Paola's Organic Market
# 123                   30000.00                                      Banking
# 124                    8689.48                                  Local Store
#
#      Year  Month Month Name
# 0    2024      1        Jan
# 1    2024      1        Jan
# 2    2024      1        Jan
# 3    2024      1        Jan
# 4    2024      1        Jan
# 5    2024      1        Jan
# 6    2024      2        Feb
# 7    2024      2        Feb
# 8    2024      2        Feb
# 9    2024      2        Feb
# 10   2024      2        Feb
# 11   2024      1        Jan
# 12   2024      1        Jan
# 13   2024      4        Apr
# 14   2024      4        Apr
# 15   2024      4        Apr
# 16   2024      5        May
# 17   2024      5        May
# 18   2024      8        Aug
# 19   2024     11        Nov
# 20   2024     11        Nov
# 21   2024     11        Nov
# 22   2024     11        Nov
# 23   2024     11        Nov
# 24   2024     11        Nov
# 25   2024     12        Dec
# 26   2024     12        Dec
# 27   2024     12        Dec
# 28   2024      3        Mar
# 29   2024      3        Mar
# 30   2024      3        Mar
# 31   2024      3        Mar
# 32   2024      3        Mar
# 33   2024      3        Mar
# 34   2024      3        Mar
# 35   2024      3        Mar
# 36   2024      3        Mar
# 37   2024      3        Mar
# 38   2024      3        Mar
# 39   2024      3        Mar
# 40   2024      3        Mar
# 41   2024      3        Mar
# 42   2024      3        Mar
# 43   2024      3        Mar
# 44   2024      3        Mar
# 45   2024      3        Mar
# 46   2024      3        Mar
# 47   2024      3        Mar
# 48   2024      3        Mar
# 49   2024      3        Mar
# 50   2024      3        Mar
# 51   2024      3        Mar
# 52   2024      5        May
# 53   2024     10        Oct
# 54   2024     11        Nov
# 55   2024     11        Nov
# 56   2024     11        Nov
# 57   2024     11        Nov
# 58   2024     12        Dec
# 59   2024      4        Apr
# 60   2024      4        Apr
# 61   2024      4        Apr
# 62   2024      4        Apr
# 63   2024      4        Apr
# 64   2024      4        Apr
# 65   2024      4        Apr
# 66   2024      4        Apr
# 67   2024      4        Apr
# 68   2024      4        Apr
# 69   2024      2        Feb
# 70   2024      5        May
# 71   2024      5        May
# 72   2024      5        May
# 73   2024      5        May
# 74   2024      5        May
# 75   2024      5        May
# 76   2024      5        May
# 77   2024      5        May
# 78   2024      5        May
# 79   2024      5        May
# 80   2024      5        May
# 81   2024      3        Mar
# 82   2024      6        Jun
# 83   2024      6        Jun
# 84   2024      1        Jan
# 85   2024      1        Jan
# 86   2024      1        Jan
# 87   2024      3        Mar
# 88   2024      4        Apr
# 89   2024      5        May
# 90   2024      8        Aug
# 91   2024     10        Oct
# 92   2024     10        Oct
# 93   2024     10        Oct
# 94   2024     10        Oct
# 95   2024     11        Nov
# 96   2024     12        Dec
# 97   2024     12        Dec
# 98   2024     12        Dec
# 99   2024      7        Jul
# 100  2024      7        Jul
# 101  2024      7        Jul
# 102  2024      7        Jul
# 103  2024      7        Jul
# 104  2024      7        Jul
# 105  2024      7        Jul
# 106  2024      7        Jul
# 107  2024      7        Jul
# 108  2024      7        Jul
# 109  2024      7        Jul
# 110  2024      7        Jul
# 111  2024      1        Jan
# 112  2024      7        Jul
# 113  2024      9        Sep
# 114  2024     12        Dec
# 115  2024     12        Dec
# 116  2024     12        Dec
# 117  2024      8        Aug
# 118  2024      8        Aug
# 119  2024      8        Aug
# 120  2024      8        Aug
# 121  2024      8        Aug
# 122  2024      8        Aug
# 123  2024      8        Aug
# 124  2024      8        Aug

# %%
# For Income rows, assign Name / Description to Category
df['Category'] = np.where(df['Expense/Income'] == 'Income', df['Name / Description'], df['Category'])
df
# Out:
#          Date               Name / Description Expense/Income  \
# 0    19/01/24                 TRANSF. CLIENTE          Income
# 1    19/01/24          TRANSFERENCIA INMEDIATA         Income
# 2    22/01/24                      IMP PAIS SD        Expense
# 3    22/01/24                   APPLE.COM/BILL        Expense
# 4    22/01/24                       RG 4815/20        Expense
# 5    23/01/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 6    28/02/24                 TRANSF. CLIENTE          Income
# 7    29/02/24               OPENPAY*VIDA POINT        Expense
# 8    29/02/24                   DIA TIENDA 268        Expense
# 9    29/02/24                           FEI LI        Expense
# 10   29/02/24                   MERPAGO*HAKUNA        Expense
# 11   01/03/24                INTERESES GANADOS         Income
# 12   01/03/24              JULIO CESAR ESTRADA        Expense
# 13   04/03/24                 TRANSF. CLIENTE          Income
# 14   04/03/24                   DIA TIENDA 679        Expense
# 15   04/03/24                           FEI LI        Expense
# 16   05/03/24                COTO SUCURSAL 163        Expense
# 17   05/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 18   08/03/24                 TRANSF. CLIENTE          Income
# 19   11/03/24                      IMP PAIS SD        Expense
# 20   11/03/24                   DIA TIENDA 268        Expense
# 21   11/03/24                   DIA TIENDA 679        Expense
# 22   11/03/24                           FEI LI        Expense
# 23   11/03/24                   APPLE.COM/BILL        Expense
# 24   11/03/24                       RG 4815/20        Expense
# 25   12/03/24                COTO SUCURSAL 163        Expense
# 26   12/03/24                  MERPAGO*JUANLIN        Expense
# 27   12/03/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 28   13/03/24                   DIA TIENDA 679        Expense
# 29   13/03/24                           FEI LI        Expense
# 30   14/03/24                 TRANSF. CLIENTE          Income
# 31   14/03/24                 VERDULERIA PAOLA        Expense
# 32   14/03/24                           FEI LI        Expense
# 33   14/03/24                   DIA TIENDA 268        Expense
# 34   15/03/24                   DIA TIENDA 679        Expense
# 35   15/03/24              JULIO CESAR ESTRADA        Expense
# 36   18/03/24                 TRANSF. CLIENTE          Income
# 37   18/03/24                 TRANSF. CLIENTE          Income
# 38   18/03/24                 VERDULERIA PAOLA        Expense
# 39   18/03/24              JULIO CESAR ESTRADA        Expense
# 40   18/03/24                           FEI LI        Expense
# 41   18/03/24         PVS*SUPER URUBURU JOSE E        Expense
# 42   18/03/24                        FARMACITY        Expense
# 43   18/03/24                   MERPAGO*HAKUNA        Expense
# 44   18/03/24                   DIA TIENDA 679        Expense
# 45   18/03/24                   DIA TIENDA 268        Expense
# 46   18/03/24                COTO SUCURSAL 163        Expense
# 47   03/04/24                INTERESES GANADOS         Income
# 48   03/04/24                 TRANSF. CLIENTE          Income
# 49   03/04/24              JULIO CESAR ESTRADA        Expense
# 50   03/04/24                COTO SUCURSAL 163        Expense
# 51   03/04/24         PVS*SUPER URUBURU JOSE E        Expense
# 52   05/04/24                   DIA TIENDA 268        Expense
# 53   10/04/24                 TRANSF. CLIENTE          Income
# 54   11/04/24                   MERPAGO*HAKUNA        Expense
# 55   11/04/24                   DIA TIENDA 268        Expense
# 56   11/04/24                 VERDULERIA PAOLA        Expense
# 57   11/04/24                           FEI LI        Expense
# 58   12/04/24                   DIA TIENDA 679        Expense
# 59   15/04/24                 VERDULERIA PAOLA        Expense
# 60   15/04/24                  MERPAGO*JUANLIN        Expense
# 61   15/04/24                         PIGMENTO        Expense
# 62   15/04/24                           FEI LI        Expense
# 63   16/04/24                   DIA TIENDA 268        Expense
# 64   16/04/24                           FEI LI        Expense
# 65   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 66   22/04/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 67   22/04/24                         PIGMENTO        Expense
# 68   23/04/24                 VERDULERIA PAOLA        Expense
# 69   02/05/24                INTERESES GANADOS         Income
# 70   24/05/24                 TRANSF. CLIENTE          Income
# 71   27/05/24         MERPAGO*LANATURALEZA1855        Expense
# 72   27/05/24           Market Avenida Sta. Fe        Expense
# 73   27/05/24                   DIA TIENDA 679        Expense
# 74   28/05/24                       NEW GARDEN        Expense
# 75   28/05/24                  MERPAGO*JUANLIN        Expense
# 76   29/05/24                COTO SUCURSAL 163        Expense
# 77   30/05/24         MERPAGO*LANATURALEZA1855        Expense
# 78   30/05/24                         LA FINCA        Expense
# 79   30/05/24                   DIA TIENDA 268        Expense
# 80   31/05/24                  MERPAGO*JUANLIN        Expense
# 81   03/06/24                INTERESES GANADOS         Income
# 82   06/06/24                  MERPAGO*JUANLIN        Expense
# 83   06/06/24                       NEW GARDEN        Expense
# 84   01/07/24                INTERESES GANADOS         Income
# 85   01/07/24                 TRANSF. CLIENTE          Income
# 86   01/07/24                    TRANSFERENCIA        Expense
# 87   03/07/24                COTO SUCURSAL 163        Expense
# 88   04/07/24   TRANSF. CLIENTE TEJERINA MARIA         Income
# 89   05/07/24                       NEW GARDEN        Expense
# 90   08/07/24                 VERDULERIA PAOLA        Expense
# 91   10/07/24                      IMP PAIS SD        Expense
# 92   10/07/24                   APPLE.COM BILL        Expense
# 93   10/07/24                COTO SUCURSAL 163        Expense
# 94   10/07/24                       RG 4815/20        Expense
# 95   11/07/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 96   12/07/24                  MERPAGO*JUANLIN        Expense
# 97   12/07/24                 VERDULERIA PAOLA        Expense
# 98   12/07/24                       NEW GARDEN        Expense
# 99   15/07/24                 TRANSF. CLIENTE          Income
# 100  15/07/24                   DIA TIENDA 268        Expense
# 101  15/07/24                    TRANSFERENCIA        Expense
# 102  15/07/24                    TRANSFERENCIA        Expense
# 103  16/07/24                   DIA TIENDA 679        Expense
# 104  19/07/24                    TRANSFERENCIA        Expense
# 105  22/07/24                 TRANSF. CLIENTE          Income
# 106  22/07/24                    TRANSFERENCIA        Expense
# 107  22/07/24                   DIA TIENDA 679        Expense
# 108  25/07/24  REINTEGRO MODO. 100% en tu Prim         Income
# 109  25/07/24  REINTEGRO MODO. 20% en cualquie         Income
# 110  29/07/24                    TRANSFERENCIA        Expense
# 111  01/08/24                INTERESES GANADOS         Income
# 112  07/08/24                 TRANSF. CLIENTE          Income
# 113  09/08/24                 VERDULERIA PAOLA        Expense
# 114  12/08/24                      IMP PAIS SD        Expense
# 115  12/08/24                   APPLE.COM/BILL        Expense
# 116  12/08/24                       RG 4815/20        Expense
# 117  13/08/24      IVA SERV DIGIT-RG AFIP 4240        Expense
# 118  26/08/24                 TRANSF. CLIENTE          Income
# 119  26/08/24                 VERDULERIA PAOLA        Expense
# 120  26/08/24                    TRANSFERENCIA        Expense
# 121  26/08/24                   DIA TIENDA 679        Expense
# 122  27/08/24                 VERDULERIA PAOLA        Expense
# 123  28/08/24                 TRANSF. CLIENTE          Income
# 124  28/08/24                COTO SUCURSAL 163        Expense
#
#      Amount (Argentinian Peso)                                     Category  \
# 0                      2000.00                             TRANSF. CLIENTE
# 1                       980.00                      TRANSFERENCIA INMEDIATA
# 2                       130.49  Important Payment for Software Subscription
# 3                      1731.30                                   Apple Bill
# 4                       489.36                                Utility Bills
# 5                       363.57                                     Services
# 6                     30000.00                             TRANSF. CLIENTE
# 7                      2900.00                        Openpay Point of Sale
# 8                      3518.75                                    Groceries
# 9                      3000.00                                       Fei Li
# 10                     1802.50                          Merpage Transaction
# 11                        0.07                            INTERESES GANADOS
# 12                     2593.00                         Julio Cesar Estravia
# 13                    10000.00                             TRANSF. CLIENTE
# 14                     6310.00                                    Groceries
# 15                     5800.00                                       Fei Li
# 16                     3870.38                                  Local Store
# 17                     7500.00                                    Groceries
# 18                    40000.00                             TRANSF. CLIENTE
# 19                      202.48  Important Payment for Software Subscription
# 20                     2690.00                                    Groceries
# 21                     4970.00                                    Groceries
# 22                     3000.00                                       Fei Li
# 23                     2705.95                                   Apple Bill
# 24                      759.31                                Utility Bills
# 25                     8790.73                                  Local Store
# 26                     2850.00                          Merpage Transaction
# 27                      568.24                                     Services
# 28                     3557.90                                    Groceries
# 29                     2950.00                                       Fei Li
# 30                    30000.00                             TRANSF. CLIENTE
# 31                     1700.00                       Paola's Organic Market
# 32                     3000.00                                       Fei Li
# 33                     3829.50                                    Groceries
# 34                     8620.05                                    Groceries
# 35                     1360.00                         Julio Cesar Estravia
# 36                    10000.00                             TRANSF. CLIENTE
# 37                    20000.00                             TRANSF. CLIENTE
# 38                     1215.00                       Paola's Organic Market
# 39                      620.00                         Julio Cesar Estravia
# 40                     3000.00                                       Fei Li
# 41                     6750.00                                    Groceries
# 42                    12006.04                                   Healthcare
# 43                     1767.50                          Merpage Transaction
# 44                     3779.00                                    Groceries
# 45                     7603.15                                    Groceries
# 46                    13184.08                                  Local Store
# 47                        0.46                            INTERESES GANADOS
# 48                    20000.00                             TRANSF. CLIENTE
# 49                     4323.00                         Julio Cesar Estravia
# 50                     6815.93                                  Local Store
# 51                     7280.00                                    Groceries
# 52                     1974.00                                    Groceries
# 53                    50000.00                             TRANSF. CLIENTE
# 54                     1767.50                          Merpage Transaction
# 55                     6505.10                                    Groceries
# 56                     2095.00                       Paola's Organic Market
# 57                     5200.00                                       Fei Li
# 58                     6789.00                                    Groceries
# 59                     7311.00                       Paola's Organic Market
# 60                     3000.00                          Merpage Transaction
# 61                     2790.00                                      Pigment
# 62                     5900.00                                       Fei Li
# 63                     4369.00                                    Groceries
# 64                     4650.00                                       Fei Li
# 65                     3000.00               TRANSF. CLIENTE TEJERINA MARIA
# 66                     7600.00               TRANSF. CLIENTE TEJERINA MARIA
# 67                     4218.57                                      Pigment
# 68                     5885.00                       Paola's Organic Market
# 69                        0.26                            INTERESES GANADOS
# 70                   100000.00                             TRANSF. CLIENTE
# 71                    11900.00                          Merpage Transaction
# 72                     8836.44                                 Local Market
# 73                     8578.60                                    Groceries
# 74                     7495.00                                   New Garden
# 75                     4700.00                          Merpage Transaction
# 76                    14979.32                                  Local Store
# 77                     5800.00                          Merpage Transaction
# 78                     7760.00                                     La Finca
# 79                     4237.40                                    Groceries
# 80                     7840.00                          Merpage Transaction
# 81                        0.73                            INTERESES GANADOS
# 82                    14000.00                          Merpage Transaction
# 83                     4400.00                                   New Garden
# 84                        0.15                            INTERESES GANADOS
# 85                   100000.00                             TRANSF. CLIENTE
# 86                    30000.00                                      Banking
# 87                    19067.60                                  Local Store
# 88                    10000.00               TRANSF. CLIENTE TEJERINA MARIA
# 89                     9400.00                                   New Garden
# 90                    11287.00                       Paola's Organic Market
# 91                      219.70  Important Payment for Software Subscription
# 92                     2900.30                                   Apple Bill
# 93                    11432.29                                  Local Store
# 94                      823.89                                Utility Bills
# 95                      609.06                                     Services
# 96                    10750.00                          Merpage Transaction
# 97                     4338.00                       Paola's Organic Market
# 98                     4400.00                                   New Garden
# 99                    50000.00                             TRANSF. CLIENTE
# 100                    9481.70                                    Groceries
# 101                   20000.00                                      Banking
# 102                   10000.00                                      Banking
# 103                    7595.90                                    Groceries
# 104                    8388.09                                      Banking
# 105                   50000.00                             TRANSF. CLIENTE
# 106                   30000.00                                      Banking
# 107                    9075.41                                    Groceries
# 108                    5000.00              REINTEGRO MODO. 100% en tu Prim
# 109                    1000.00              REINTEGRO MODO. 20% en cualquie
# 110                   16924.00                                      Banking
# 111                       0.94                            INTERESES GANADOS
# 112                   20000.00                             TRANSF. CLIENTE
# 113                    3612.00                       Paola's Organic Market
# 114                     224.60  Important Payment for Software Subscription
# 115                    2972.06                                   Apple Bill
# 116                     842.28                                Utility Bills
# 117                     624.13                                     Services
# 118                   50000.00                             TRANSF. CLIENTE
# 119                    8552.00                       Paola's Organic Market
# 120                   30000.00                                      Banking
# 121                    5436.25                                    Groceries
# 122                    7346.00                       Paola's Organic Market
# 123                   30000.00                             TRANSF. CLIENTE
# 124                    8689.48                                  Local Store
#
#      Year  Month Month Name
# 0    2024      1        Jan
# 1    2024      1        Jan
# 2    2024      1        Jan
# 3    2024      1        Jan
# 4    2024      1        Jan
# 5    2024      1        Jan
# 6    2024      2        Feb
# 7    2024      2        Feb
# 8    2024      2        Feb
# 9    2024      2        Feb
# 10   2024      2        Feb
# 11   2024      1        Jan
# 12   2024      1        Jan
# 13   2024      4        Apr
# 14   2024      4        Apr
# 15   2024      4        Apr
# 16   2024      5        May
# 17   2024      5        May
# 18   2024      8        Aug
# 19   2024     11        Nov
# 20   2024     11        Nov
# 21   2024     11        Nov
# 22   2024     11        Nov
# 23   2024     11        Nov
# 24   2024     11        Nov
# 25   2024     12        Dec
# 26   2024     12        Dec
# 27   2024     12        Dec
# 28   2024      3        Mar
# 29   2024      3        Mar
# 30   2024      3        Mar
# 31   2024      3        Mar
# 32   2024      3        Mar
# 33   2024      3        Mar
# 34   2024      3        Mar
# 35   2024      3        Mar
# 36   2024      3        Mar
# 37   2024      3        Mar
# 38   2024      3        Mar
# 39   2024      3        Mar
# 40   2024      3        Mar
# 41   2024      3        Mar
# 42   2024      3        Mar
# 43   2024      3        Mar
# 44   2024      3        Mar
# 45   2024      3        Mar
# 46   2024      3        Mar
# 47   2024      3        Mar
# 48   2024      3        Mar
# 49   2024      3        Mar
# 50   2024      3        Mar
# 51   2024      3        Mar
# 52   2024      5        May
# 53   2024     10        Oct
# 54   2024     11        Nov
# 55   2024     11        Nov
# 56   2024     11        Nov
# 57   2024     11        Nov
# 58   2024     12        Dec
# 59   2024      4        Apr
# 60   2024      4        Apr
# 61   2024      4        Apr
# 62   2024      4        Apr
# 63   2024      4        Apr
# 64   2024      4        Apr
# 65   2024      4        Apr
# 66   2024      4        Apr
# 67   2024      4        Apr
# 68   2024      4        Apr
# 69   2024      2        Feb
# 70   2024      5        May
# 71   2024      5        May
# 72   2024      5        May
# 73   2024      5        May
# 74   2024      5        May
# 75   2024      5        May
# 76   2024      5        May
# 77   2024      5        May
# 78   2024      5        May
# 79   2024      5        May
# 80   2024      5        May
# 81   2024      3        Mar
# 82   2024      6        Jun
# 83   2024      6        Jun
# 84   2024      1        Jan
# 85   2024      1        Jan
# 86   2024      1        Jan
# 87   2024      3        Mar
# 88   2024      4        Apr
# 89   2024      5        May
# 90   2024      8        Aug
# 91   2024     10        Oct
# 92   2024     10        Oct
# 93   2024     10        Oct
# 94   2024     10        Oct
# 95   2024     11        Nov
# 96   2024     12        Dec
# 97   2024     12        Dec
# 98   2024     12        Dec
# 99   2024      7        Jul
# 100  2024      7        Jul
# 101  2024      7        Jul
# 102  2024      7        Jul
# 103  2024      7        Jul
# 104  2024      7        Jul
# 105  2024      7        Jul
# 106  2024      7        Jul
# 107  2024      7        Jul
# 108  2024      7        Jul
# 109  2024      7        Jul
# 110  2024      7        Jul
# 111  2024      1        Jan
# 112  2024      7        Jul
# 113  2024      9        Sep
# 114  2024     12        Dec
# 115  2024     12        Dec
# 116  2024     12        Dec
# 117  2024      8        Aug
# 118  2024      8        Aug
# 119  2024      8        Aug
# 120  2024      8        Aug
# 121  2024      8        Aug
# 122  2024      8        Aug
# 123  2024      8        Aug
# 124  2024      8        Aug

# %% [markdown]
# ### Make pie charts - Income/ Expense breakdown

# %%
def make_pie_chart(df, year, label, top_n=None):
    """
    Creates a pie chart showing expense/income breakdown
    Args:
        df: Pandas DataFrame with financial data
        year: Year to filter
        label: 'Expense' or 'Income'
        top_n: Optional - show only top N categories
    """
    # Validate inputs
    if label not in ['Expense', 'Income']:
        raise ValueError("Label must be 'Expense' or 'Income'")
        
    # Filter data
    sub_df = df[(df['Expense/Income'] == label) & (df['Year'] == year)]
    if sub_df.empty:
        return px.pie(title=f"No {label} data for year {year}")
    
    # Group and sort
    grouped = sub_df.groupby('Category')['Amount (Argentinian Peso)'].sum()
    grouped = grouped.sort_values(ascending=False)
    
    # Limit categories if specified
    if top_n and len(grouped) > top_n:
        others_sum = grouped[top_n:].sum()
        grouped = grouped[:top_n]
        grouped['Others'] = others_sum
    
    # Create DataFrame for plotting
    plot_df = grouped.reset_index()
    
    # Calculate totals
    total_expense = df[(df['Expense/Income'] == 'Expense') & 
                      (df['Year'] == year)]['Amount (Argentinian Peso)'].sum()
    total_income = df[(df['Expense/Income'] == 'Income') & 
                     (df['Year'] == year)]['Amount (Argentinian Peso)'].sum()
    
    # Format values
    total_text = f"$ {'{:,.0f}'.format(total_expense if label=='Expense' else total_income)}"
    saving_rate_text = ""
    if label == 'Expense' and total_income > 0:
        saving_rate = round((total_income - total_expense)/total_income*100)
        saving_rate_text = f": Saving Rate {saving_rate}%"
    
    # Create pie chart
    fig = px.pie(plot_df, 
                 values='Amount (Argentinian Peso)', 
                 names='Category',
                 color_discrete_sequence=px.colors.qualitative.Set2)
    
    # Update layout
    fig.update_traces(textposition='inside', 
                     direction='clockwise', 
                     hole=0.3,
                     textinfo="label+percent")
    
    fig.update_layout(
        uniformtext_minsize=3,
        uniformtext_mode='hide',
        title=dict(text=f"{label} Breakdown {year}{saving_rate_text}"),
        annotations=[dict(
            text=total_text,
            x=0.5,
            y=0.5,
            font_size=12,
            showarrow=False
        )]
    )
    
    return fig

# %%
income_pie_fig_2024 = make_pie_chart(df, 2024, 'Income',top_n=5)
income_pie_fig_2024

# %% [markdown]
# ### Make bar charts over months in a year

# %%
def make_monthly_bar_chart(df, year, label):
    df = df[(df['Expense/Income'] == label) & (df['Year'] == year)]
    total_by_month = (df.groupby(['Month', 'Month Name'])['Amount (Argentinian Peso)'].sum()
                        .to_frame()
                        .reset_index()
                        .sort_values(by='Month')  
                        .reset_index(drop=True))
    if label == "Income":
        color_scale = px.colors.sequential.YlGn
    if label == "Expense":
        color_scale = px.colors.sequential.OrRd
    
    bar_fig = px.bar(total_by_month, x='Month Name', y='Amount (Argentinian Peso)', text_auto='.2s', title=label+" per month", color='Amount (Argentinian Peso)', color_continuous_scale=color_scale)
    # bar_fig.update_traces(marker_color='lightslategrey')
    
    return bar_fig

# %%
income_monthly_2024 = make_monthly_bar_chart(df, 2024, 'Income')
income_monthly_2024

# %% [markdown]
# ### Putting all charts together into tabs for 2022/2023

# %%
# Pie charts
income_pie_fig_2024 = make_pie_chart(df, 2024, 'Income')
expense_pie_fig_2024 = make_pie_chart(df, 2024, 'Expense')  

# Bar charts
income_monthly_2024 = make_monthly_bar_chart(df, 2024, 'Income')
expense_monthly_2024 = make_monthly_bar_chart(df, 2024, 'Expense')


# Create tabs
tabs = pn.Tabs(
                        ('2024', pn.Column(pn.Row(income_pie_fig_2024, expense_pie_fig_2024),
                                                pn.Row(income_monthly_2024, expense_monthly_2024)))
                )
tabs.show()
# Out:
# Launching server at http://localhost:52602

# %% [markdown]
# ### Create dashboard

# %%
# Dashboard template
template = pn.template.FastListTemplate(
    title='Personal Finance Dashboard',
    sidebar=[pn.pane.Markdown("# Income Expense analysis"), 
             pn.pane.Markdown("Overview of income and expense based on my bank transactions. Categories are obtained using local LLMs."),
             pn.pane.PNG("picture.png", sizing_mode="scale_both")
             ],
    main=[pn.Row(pn.Column(pn.Row(tabs)
                           )
                ),
                ],
    # accent_base_color="#88d8b0",
    header_background="#c0b9dd",
)

template.show()
# Out:
# Launching server at http://localhost:52604
